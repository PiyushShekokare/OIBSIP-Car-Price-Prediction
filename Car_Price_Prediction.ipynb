# %% [markdown]
# Name : Piyush Sunil Shekokare

# %% [markdown]
# DATA SCIENCE INTERNSHIP TASK 3 @ OASIS INFOBYTE

# %% [markdown]
# PROJECT NAME : CAR PRICE PREDICTION WITH MACHINE LEARNING

# %% [markdown]
# PROBLEM STATEMENT - The price of a car depends on a lot of factors like the goodwill of the brand of the car,features of the car, horsepower and the mileage it gives and many more. Car price prediction is one of the major research areas in machine learning.

# %% [markdown]
# Import the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.ensemble import ExtraTreesRegressor
import numpy as np
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# Data Preprocessing

# %%
df=pd.read_csv('/content/archive (6).zip')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
dataset = df[['Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
       'Fuel_Type', 'Selling_type', 'Transmission', 'Owner']]

# %%
dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
dataset['Current_Year'] = 2023

# %%
dataset['Age'] = dataset['Current_Year']-dataset['Year']

# %%
dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Current_Year  Age
# 0       Manual      0          2023    9
# 1       Manual      0          2023   10
# 2       Manual      0          2023    6
# 3       Manual      0          2023   12
# 4       Manual      0          2023    9

# %%
dataset.drop(['Year'],axis=1,inplace=True)

# %%
dataset.drop(['Current_Year'],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0           3.35           5.59       27000    Petrol       Dealer
# 1           4.75           9.54       43000    Diesel       Dealer
# 2           7.25           9.85        6900    Petrol       Dealer
# 3           2.85           4.15        5200    Petrol       Dealer
# 4           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0    9
# 1       Manual      0   10
# 2       Manual      0    6
# 3       Manual      0   12
# 4       Manual      0    9

# %%
print(df['Fuel_Type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0    9                 0
# 1           4.75           9.54       43000      0   10                 1
# 2           7.25           9.85        6900      0    6                 0
# 3           2.85           4.15        5200      0   12                 0
# 4           4.60           6.87       42450      0    9                 1
#
#    Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                 1                        0                    1
# 1                 0                        0                    1
# 2                 1                        0                    1
# 3                 1                        0                    1
# 4                 0                        0                    1

# %% [markdown]
# Finding pairwise correlation

# %%
dataset.corr(method ='pearson')
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner  \
# Selling_Price                 1.000000       0.878914    0.029187 -0.088344
# Present_Price                 0.878914       1.000000    0.203618  0.008058
# Driven_kms                    0.029187       0.203618    1.000000  0.089216
# Owner                        -0.088344       0.008058    0.089216  1.000000
# Age                          -0.236141       0.047192    0.524342  0.182104
# Fuel_Type_Diesel              0.552339       0.473390    0.172515 -0.053469
# Fuel_Type_Petrol             -0.540571      -0.465326   -0.172874  0.055687
# Selling_type_Individual      -0.550724      -0.512121   -0.101419  0.124269
# Transmission_Manual          -0.367128      -0.348776   -0.162510 -0.050316
#
#                               Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price           -0.236141          0.552339         -0.540571
# Present_Price            0.047192          0.473390         -0.465326
# Driven_kms               0.524342          0.172515         -0.172874
# Owner                    0.182104         -0.053469          0.055687
# Age                      1.000000         -0.064315          0.059959
# Fuel_Type_Diesel        -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol         0.059959         -0.979648          1.000000
# Selling_type_Individual  0.039896         -0.350467          0.358321
# Transmission_Manual     -0.000394         -0.098643          0.091013
#
#                          Selling_type_Individual  Transmission_Manual
# Selling_Price                          -0.550724            -0.367128
# Present_Price                          -0.512121            -0.348776
# Driven_kms                             -0.101419            -0.162510
# Owner                                   0.124269            -0.050316
# Age                                     0.039896            -0.000394
# Fuel_Type_Diesel                       -0.350467            -0.098643
# Fuel_Type_Petrol                        0.358321             0.091013
# Selling_type_Individual                 1.000000             0.063240
# Transmission_Manual                     0.063240             1.000000

# %%
corrmat = df.corr(method='pearson')
# Out:
# <ipython-input-29-1353ac793ee1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr(method='pearson')

# %%
corrmat.index
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Driven_kms', 'Owner'], dtype='object')

# %%
corrmat = df.corr(method='pearson')
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(method='pearson'),annot=True,cmap="RdYlGn")
# Out:
# <ipython-input-32-acf5e9e9f65c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr(method='pearson')

# %%
corrmat = dataset.corr(method='pearson')
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map of the corerlation of the features
g=sns.heatmap(dataset[top_corr_features].corr(method='pearson'),annot=True,cmap="RdYlGn")

# %%
dataset
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0    9                 0
# 1             4.75           9.54       43000      0   10                 1
# 2             7.25           9.85        6900      0    6                 0
# 3             2.85           4.15        5200      0   12                 0
# 4             4.60           6.87       42450      0    9                 1
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0    7                 1
# 297           4.00           5.90       60000      0    8                 0
# 298           3.35          11.00       87934      0   14                 0
# 299          11.50          12.50        9000      0    6                 1
# 300           5.30           5.90        5464      0    7                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                   1                        0                    1
# 1                   0                        0                    1
# 2                   1                        0                    1
# 3                   1                        0                    1
# 4                   0                        0                    1
# ..                ...                      ...                  ...
# 296                 0                        0                    1
# 297                 1                        0                    1
# 298                 1                        0                    1
# 299                 0                        0                    1
# 300                 1                        0                    1
#
# [301 rows x 9 columns]

# %%
dataset.iloc[:,0]
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %% [markdown]
# Extracting dependent and independent variables

# %%
X= dataset.iloc[:,1:]
Y = dataset.iloc[:,0]

# %%
X.head()
# Out:
#    Present_Price  Driven_kms  Owner  Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0           5.59       27000      0    9                 0                 1
# 1           9.54       43000      0   10                 1                 0
# 2           9.85        6900      0    6                 0                 1
# 3           4.15        5200      0   12                 0                 1
# 4           6.87       42450      0    9                 1                 0
#
#    Selling_type_Individual  Transmission_Manual
# 0                        0                    1
# 1                        0                    1
# 2                        0                    1
# 3                        0                    1
# 4                        0                    1

# %%
Y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
model = ExtraTreesRegressor()
model.fit(X,Y)
# Out:
# ExtraTreesRegressor()

# %% [markdown]
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org

# %%
print(model.feature_importances_)
# Out:
# [3.91600797e-01 3.96704760e-02 3.41442398e-04 7.72371507e-02
#  2.21239151e-01 1.17020924e-02 1.15004779e-01 1.43204111e-01]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.title('Feature Importances')
plt.show()
